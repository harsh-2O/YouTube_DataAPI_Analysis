# %%
import os 
from googleapiclient.discovery import build

# %%
def google_api(id):
    
    os.environ["0AUTHLIB_INSECURE_TRANSPORT"] = "1"
    api_key = "AIzaSyCfG3uF4Oiq1TCMZfYroYWAlpqdjHTgGak"

    youtube = build('youtube','v3',developerKey=api_key)
    request = youtube.commentThreads().list(
      part="id,snippet",
      maxResults=1500,
      order="relevance",
      videoId = id
  )

    response = request.execute()
    print(response)
    return response
  
response = google_api("C3P-b5Szz44")
# Out:
# {'kind': 'youtube#commentThreadListResponse', 'etag': '-iDq7-uDoxw0czsLgzR1H2BpNtM', 'nextPageToken': '...', 'pageInfo': {'totalResults': 98, 'resultsPerPage': 100}, 'items': [{'kind': 'youtube#commentThread', 'etag': 'GhmuvwIHQCWE4Q08F40897q4Ldw', 'id': 'UgygUCRe_lhAQfup5Ah4AaABAg', 'snippet': {'videoId': 'C3P-b5Szz44', 'topLevelComment': {'kind': 'youtube#comment', 'etag': '1GaNBY4tSJd8NIMzfdNfz41zNb4', 'id': 'UgygUCRe_lhAQfup5Ah4AaABAg', 'snippet': {'videoId': 'C3P-b5Szz44', 'textDisplay': 'It was a pleasure building doors with you sir \U0001fae1 never seen anyone be a better human wrecking ball than you', 'textOriginal': 'It was a pleasure building doors with you sir \U0001fae1 never seen anyone be a better human wrecking ball than you', 'authorDisplayName': 'Jordan Studdard', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8ZxSm2QZXQHl5xGK7knPBPAsjAfmvu8zi0_Q6i2A=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCPjHhJ3fxgcV5Gv5uVAhNEA', 'authorChannelId': {'value': 'UCPjHhJ3fxgcV5Gv5uVAhNEA'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 5232, 'publishedAt': '2022-10-05T21:57:48Z', 'updatedAt': '2022-10-05T21:57:48Z'}}, 'canReply': True, 'totalReplyCount': 27, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'fK4sRjok9jRYM1EDgt1hIRruCI4', 'id': 'Ugw1eMeVIMgyKSz-hRF4AaABAg', 'snippet': {'videoId': 'C3P-b5Szz44', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'yiZB0ah8ixCXNiVf0QdgkhlqK7M', 'id': 'Ugw1eMeVIMgyKSz-hRF4AaABAg', 'snippet': {'videoId': 'C3P-b5Szz44', 'textDisplay': 'I love how after so many years of filming in and around this space, he still finds a such a creative new shot for the intro to the video. Mad respect, Casey!', 'textOriginal': 'I love how after so many years of filming in and around this space, he still finds a such a creative new shot for the intro to the video. Mad respect, Casey!', 'authorDisplayName': 'JChaseFilms', 'authorProfileImageUrl': 'https://yt3.ggpht.com/d4vkGQx4dkOgoLyWm6tDf-Rd9ieXFHVS4eR645Q1Pppie-5dgp4SvEfK8gNDf0Sf9E5O9Sj4=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCYnDCKQwl75NjX7AbO58fqQ', 'authorChannelId': {'value': 'UCYnDCKQwl75NjX7AbO58fqQ'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 47, 'publishedAt': '2022-10-06T02:41:40Z', 'updatedAt': '2022-10-06T02:41:40Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'W1k3-4OuVFtqOeGIeNl4Toa-Xio', 'id': 'Ugx4KqK8Scv64Z9PmsJ4AaABAg', 'snippet': {'videoId': 'C3P-b5Szz44', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'R4MNsyfZgP2deKCsxwGNhLu0GtI', 'id': 'Ugx4KqK8Scv64Z9PmsJ4AaABAg', 'snippet': {'videoId': 'C3P-b5Szz44', 'textDisplay': 'This feels so freaking nostalgic. Almost like the world is healing. Everything is right. Casey is back in the city. His studio is back. All is right in the world. Idk how to explain it, but the thought is just so comforting.', 'textOriginal': 'This feels so freaking nostalgic. Almost like the world is healing. Everything is right. Casey is back in the city. His studio is back. All is right in the world. Idk how to explain it, but the thought is just so comforting.', 'authorDisplayName': 'Nins', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-6jhMO-DAffcKIvtuqOKM8Cqfk0Tr8dwcwqw=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCY6lg87kC73mGSnuw_t7U0g', 'authorChannelId': {'value': 'UCY6lg87kC73mGSnuw_t7U0g'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 494, 'publishedAt': '2022-10-06T02:39:24Z', 'updatedAt': '2022-10-06T02:39:24Z'}}, 'canReply': True, 'totalReplyCount': 8, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'Vip1vZvhoaaAWBvZcZw04zexje0', 'id': 'UgzU8MeiKyEDEHLISXp4AaABAg', 'snippet': {'videoId': 'C3P-b5Szz44', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'FSF8CS0buY5GFWbpSj8a02sKFIU', 'id': 'UgzU8MeiKyEDEHLISXp4AaABAg', 'snippet': {'video ...

# %%
import pandas as pd 
def create_df_author_comments():
    authorname = []
    comments = []
    like_Count = []
    for i in range(len(response["items"])):
        authorname.append(response["items"][i]["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"])
        comments.append(response["items"][i]["snippet"]["topLevelComment"]["snippet"]["textOriginal"])
        like_Count.append(response["items"][i]["snippet"]["topLevelComment"]["snippet"]["likeCount"])
        df = pd.DataFrame({'Comments':comments,"LikeCount":like_Count}, index = authorname) 
    return df 
df = create_df_author_comments()
df.head(50)
# Out:
#                                                                             Comments  \
# Jordan Studdard                    It was a pleasure building doors with you sir ...
# JChaseFilms                        I love how after so many years of filming in a...
# Nins                               This feels so freaking nostalgic. Almost like ...
# Tanush Bhatt                       Gotta love classic 'Casey solves little proble...
# Tinkle Me 4 [S]E.X                 Love seeing Casey back and he is the only pers...
# Dheerej Singh                      Only Casey Neistat can make a 7-minute film ab...
# briansmobile1                      The funnest thing about the "secret door" is h...
# Khichle Sid                        just seeing casey up running and back on youtu...
# Gawx Art                                                      This makes me so happy
# Denny Sell                         Love seeing Casey back and he is the only pers...
# penguinsix                         In my 56 years, no one has ever told me I can ...
# []#*°• jelly_KR3W•°*#[]:7 •ASOUE•  Casey. Welcome back to NYC and back to your st...
# Tinkle Me 4 [S]E.X                 I love how after so many years of filming in a...
# The Groovy Guitar Dude             Casey’s vlogs ALMOST didn’t feel like Casey’s ...
# neo VIVE                           Came here for the secret door, left with a smi...
# VonVoidGT                          Great and fun to see, Casey getting back into ...
# Frank Alfieri                      Casey I love you man!  That childlike joy and ...
# Justin Delp                        Casey’s artistic work and his ability to enter...
# Tom Elvin                          He’s done it again. He’s literally made buildi...
# The Story Till Now                     I missed these videos in my life so much. 😭👍🏻
# Magi Rita                          I absolutely love the joy with which Casey liv...
# plazacamacho                       Quiero un estudio como ese.   Saludos desde Ci...
# kwyjiboss                          Casey. Welcome back to NYC and back to your st...
# Eric Altenburg                     Casey’s enjoyment with that door is the same e...
def cleaning_comments(comment):
    comment = re.sub("[🤣|🤭|🤣|😁|🤭|❤️|👍|🏴|😣|😠|💪|🙏|✊|🧔🏾|🏾|😳]+",'',comment)
    comment = re.sub("[0-9]+","",comment)
    comment = re.sub("[\:|\@|\)|\*|\.|\$|\!|\?|\,|\%|\"]+"," ",comment)
    comment = re.sub("[💁|🌾|😎|♥|🤷‍♂]+","",comment)
    comment = re.sub("[\(|\-|\”|\“|\#|\!|\/|\«|\»|\&]+","",comment)
    comment = re.sub("\n"," ",comment)
    comment = re.sub('[\'|🇵🇰|\;|\！]+','',comment)
    comment = re.sub('[^a-zA-Z]',' ',comment)
    return comment

df["Comments"] = df["Comments"].apply(cleaning_comments)

# %% [markdown]
# ##### 2. Converting Comments to lowerCase

# %%
lower = lambda comment:comment.lower()
df['Comments'] = df['Comments'].apply(lower)
df.head(25)
# Out:
#                                                                             Comments  \
# Jordan Studdard                    it was a pleasure building doors with you sir ...
# JChaseFilms                        i love how after so many years of filming in a...
# Nins                               this feels so freaking nostalgic  almost like ...
# Tanush Bhatt                       gotta love classic casey solves little problem...
# Tinkle Me 4 [S]E.X                 love seeing casey back and he is the only pers...
# Dheerej Singh                      only casey neistat can make a minute film abou...
# briansmobile1                      the funnest thing about the  secret door  is h...
# Khichle Sid                        just seeing casey up running and back on youtu...
# Gawx Art                                                      this makes me so happy
# Denny Sell                         love seeing casey back and he is the only pers...
# penguinsix                         in my  years  no one has ever told me i can bu...
# []#*°• jelly_KR3W•°*#[]:7 •ASOUE•  casey  welcome back to nyc and back to your st...
# Tinkle Me 4 [S]E.X                 i love how after so many years of filming in a...
# The Groovy Guitar Dude             casey s vlogs almost didn t feel like casey s ...
# neo VIVE                           came here for the secret door  left with a smi...
# VonVoidGT                          great and fun to see  casey getting back into ...
# Frank Alfieri                      casey i love you man   that childlike joy and ...
# Justin Delp                        casey s artistic work and his ability to enter...
# Tom Elvin                          he s done it again  he s literally made buildi...
# The Story Till Now                      i missed these videos in my life so much
# Magi Rita                          i absolutely love the joy with which casey liv...
# plazacamacho                       quiero un estudio como ese    saludos desde ci...
# kwyjiboss                          casey  welcome back to nyc and back to your st...
# Eric Altenburg                     casey s enjoyment with that door is the same e...
# Edgar A.                           the feeling of nostalgia  and the happiness of...
#
#                                    LikeCount
# Jordan Studdard                         5232
# JChaseFilms                               47
# Nins                                     494
# Tanush Bhatt                             730
# Tinkle Me 4 [S]E.X                        47
# Dheerej Singh                            247
# briansmobile1                              5
# Khichle Sid                               50
# Gawx Art                                  60
# Denny Sell                               753
# penguinsix                                 4
# []#*°• jelly_KR3W•°*#[]:7 •ASOUE•         55
# Tinkle Me 4 [S]E.X                        29
# The Groovy Guitar Dude                     1
# neo VIVE                                   0
# VonVoidGT                                 10
# Frank Alfieri                             18
# Justin Delp                                3
# Tom Elvin                               2503
# The Story Till Now                         1
# Magi Rita                                  5
# plazacamacho                               0
# kwyjiboss                                  3
# Eric Altenburg                             3
# Edgar A.                                   1

# %% [markdown]
# ##### ***Removing Some Comments that became empty string after the Cleaning***

# %%
def remove_comments(df):
    #Check for the comment that has Zero length in dataframe
    zero_length_comments = df[df["Comments"].map(len)==0]
    #Taking all the indexes of the filtered comments in a list
    zero_length_comments_index = [ind for ind in zero_length_comments.index]
    #removing those comments
    df.drop(zero_length_comments_index,inplace=True)
    return df

df = remove_comments(df)
df = df.drop_duplicates(subset='Comments', keep="first")
df.head(25)
# Out:
#                                                                             Comments  \
# Jordan Studdard                    it was a pleasure building doors with you sir ...
# JChaseFilms                        i love how after so many years of filming in a...
# Nins                               this feels so freaking nostalgic  almost like ...
# Tanush Bhatt                       gotta love classic casey solves little problem...
# Tinkle Me 4 [S]E.X                 love seeing casey back and he is the only pers...
# Dheerej Singh                      only casey neistat can make a minute film abou...
# briansmobile1                      the funnest thing about the  secret door  is h...
# Khichle Sid                        just seeing casey up running and back on youtu...
# Gawx Art                                                      this makes me so happy
# penguinsix                         in my  years  no one has ever told me i can bu...
# []#*°• jelly_KR3W•°*#[]:7 •ASOUE•  casey  welcome back to nyc and back to your st...
# The Groovy Guitar Dude             casey s vlogs almost didn t feel like casey s ...
# neo VIVE                           came here for the secret door  left with a smi...
# VonVoidGT                          great and fun to see  casey getting back into ...
# Frank Alfieri                      casey i love you man   that childlike joy and ...
# Justin Delp                        casey s artistic work and his ability to enter...
# Tom Elvin                          he s done it again  he s literally made buildi...
# The Story Till Now                      i missed these videos in my life so much
# Magi Rita                          i absolutely love the joy with which casey liv...
# plazacamacho                       quiero un estudio como ese    saludos desde ci...
# kwyjiboss                          casey  welcome back to nyc and back to your st...
# Eric Altenburg                     casey s enjoyment with that door is the same e...
# Edgar A.                           the feeling of nostalgia  and the happiness of...
# 843sagev                           glad you re back casey  the king of vlogs and ...
# Night Shark 115                    i remember watching my first casey video becau...
#
#                                    LikeCount
# Jordan Studdard                         5232
# JChaseFilms                               47
# Nins                                     494
# Tanush Bhatt                             730
# Tinkle Me 4 [S]E.X                        47
# Dheerej Singh                            247
# briansmobile1                              5
# Khichle Sid                               50
# Gawx Art                                  60
# penguinsix                                 4
# []#*°• jelly_KR3W•°*#[]:7 •ASOUE•         55
# The Groovy Guitar Dude                     1
# neo VIVE                                   0
# VonVoidGT                                 10
# Frank Alfieri                             18
# Justin Delp                                3
# Tom Elvin                               2503
# The Story Till Now                         1
# Magi Rita                                  5
# plazacamacho                               0
# kwyjiboss                                  3
# Eric Altenburg                             3
# Edgar A.                                   1
# 843sagev                                   5
# Night Shark 115                            3

# %%
from textblob.blob import TextBlob

def find_subjectivity_on_single_comment(text):
    return TextBlob(text).sentiment.subjectivity

def apply_subjectivity_on_all_comments(df):
    df['Subjectivity'] = df['Comments'].apply(find_subjectivity_on_single_comment)
    return df

df = apply_subjectivity_on_all_comments(df)

def find_polarity_of_single_comment(text):
   return  TextBlob(text).sentiment.polarity

def find_polarity_of_every_comment(df):  
  df['Polarity'] = df['Comments'].apply(find_polarity_of_single_comment)
  return df 

df = find_polarity_of_every_comment(df)
df
# Out:
#                                                              Comments  \
# Jordan Studdard     it was a pleasure building doors with you sir ...
# JChaseFilms         i love how after so many years of filming in a...
# Nins                this feels so freaking nostalgic  almost like ...
# Tanush Bhatt        gotta love classic casey solves little problem...
# Tinkle Me 4 [S]E.X  love seeing casey back and he is the only pers...
# ...                                                               ...
# Shirt Agency        it shows you how talented casey is at editing ...
# Omar                your vlogs automatically make my day  im so gl...
# Rock O'clock        you bring so much joy to peoples lives  bless ...
# SocalSteve          you have brought back some good vibes  love se...
# Young Orange        casey uploading regularly is what the world ne...
#
#                     LikeCount  Subjectivity  Polarity
# Jordan Studdard          5232      0.300000  0.250000
# JChaseFilms                47      0.675758  0.168561
# Nins                      494      0.414286  0.014286
# Tanush Bhatt              730      0.577083  0.391146
# Tinkle Me 4 [S]E.X         47      0.460714  0.257143
# ...                       ...           ...       ...
# Shirt Agency                1      0.900000  0.050000
# Omar                        0      0.500000  0.250000
# Rock O'clock                0      0.200000  0.800000
# SocalSteve                  0      0.216667  0.216667
# Young Orange               43      0.306319  0.142857
#
# [83 rows x 4 columns]

# %%
analysis = lambda polarity: 'Positive' if polarity > 0 else 'Neutral' if polarity == 0 else 'Negative' 

def analysis_based_on_polarity(df):
  df['Analysis'] = df['Polarity'].apply(analysis)
  return df
  
df = analysis_based_on_polarity(df)
df
# Out:
#                                                              Comments  \
# Jordan Studdard     it was a pleasure building doors with you sir ...
# JChaseFilms         i love how after so many years of filming in a...
# Nins                this feels so freaking nostalgic  almost like ...
# Tanush Bhatt        gotta love classic casey solves little problem...
# Tinkle Me 4 [S]E.X  love seeing casey back and he is the only pers...
# ...                                                               ...
# Shirt Agency        it shows you how talented casey is at editing ...
# Omar                your vlogs automatically make my day  im so gl...
# Rock O'clock        you bring so much joy to peoples lives  bless ...
# SocalSteve          you have brought back some good vibes  love se...
# Young Orange        casey uploading regularly is what the world ne...
#
#                     LikeCount  Subjectivity  Polarity  Analysis
# Jordan Studdard          5232      0.300000  0.250000  Positive
# JChaseFilms                47      0.675758  0.168561  Positive
# Nins                      494      0.414286  0.014286  Positive
# Tanush Bhatt              730      0.577083  0.391146  Positive
# Tinkle Me 4 [S]E.X         47      0.460714  0.257143  Positive
# ...                       ...           ...       ...       ...
# Shirt Agency                1      0.900000  0.050000  Positive
# Omar                        0      0.500000  0.250000  Positive
# Rock O'clock                0      0.200000  0.800000  Positive
# SocalSteve                  0      0.216667  0.216667  Positive
# Young Orange               43      0.306319  0.142857  Positive
#
# [83 rows x 5 columns]

# %%
def print_positive_comments():
      print('Printing positive comments:\n')
      sortedDF = df.sort_values(by=['Polarity']) 
      for i in range(0, sortedDF.shape[0] ):
        if( sortedDF['Analysis'][i] == 'Positive'):
          print(str(i+1) + '> '+ sortedDF['Comments'][i])
          print()
print_positive_comments()
# Out:
# Printing positive comments:
#
# 11> this feels so freaking nostalgic  almost like the world is healing  everything is right  casey is back in the city  his studio is back  all is right in the world  idk how to explain it  but the thought is just so comforting
#
# 12> truly a delight to watch   you re the master at making the ordinary  extraordinary
#
# 70> this is by far the best thing ive seen all week   im so glad to have casey back   thank you for all the amazing you bring to us on youtube casey
#
# 71> great to see you  congratulations for your new store room thats really enjoyable to add something to room or office  you made it like treasure hunt  thank you casey for sharing  best of luck for future
#
# 72> he s done it again  he s literally made building a door an interesting thing to watch
#
# 73> echoing what everyone else has said  it is a testament to casey s storytelling that he can make what amounts to construction just a riveting  minutes
#
# 74> i can t tell if your life is really this amazing or if you re just that good at making videos
#
# 75> its   casey builds things  everything is ok
#
# 76> perfect production dude  editing  music  the whole bunch  everything suits perfect  next level dude
#
# 77> i absolutely love the joy with which casey lives  it really translates into his work  or maybe the joy his work brings him translates to how he lives  idk  regardless it s a pleasure to watch  thank you for sharing this with us casey
#
# 78> one of my favourite things is seeing casey repair and changing his studio again and again  i m actually thrilled to see it again
#
# 79> i really admire that after all this time  casey is still the best at what he does
#
# 80> casey i love you man   that childlike joy and wonder is contagious   thank you dude
#
# 81> hi casey  i wanna just remember you that everytime  you make more than  million people around the world happy with your video story  thank you sir casey
#
# 82> this makes me so happy
#
# 83> you bring so much joy to peoples lives  bless you casey

# %%
def print_negative_comments():
  print('Printing negative comments:\n')
  sortedDF = df.sort_values(by=['Polarity']) 
  for i in range(0, sortedDF.shape[0] ):
    if( sortedDF['Analysis'][i] == 'Negative'):
      print(str(i+1) + '> '+ sortedDF['Comments'][i])
      print()
print_negative_comments()
# Out:
# Printing negative comments:
#
# 1> only casey neistat can make a minute film about a door and not make it boring  i have no idea how his doing it but im loving it
#
# 2> all the little things casey adds to his videos  like this room being foreshadowed in the previous video and then showing dan in this video and those camera angles are such a delight
#
# 3> can tell the man s having fun  he even forgot about ending credits  now i need to build my secret door
#
# 4> just seeing casey up running and back on youtube is an inspiration every single vlog makes my day have to watch them over and over again

# %%
def print_neutral_comments():
  print('Printing neutral comments:\n')
  sortedDF = df.sort_values(by=['Polarity']) 
  for i in range(0, sortedDF.shape[0] ):
    if( sortedDF['Analysis'][i] == 'Neutral'):
      print(str(i+1) + '> '+ sortedDF['Comments'][i])
      print()
print_neutral_comments()
# Out:
# Printing neutral comments:
#
# 5> quiero un estudio como ese    saludos desde ciudad de m xico
#
# 6> ayo so youre saying you need help with remaking your dream room
#
# 7> cant ever have enough casey content   thank you casey
#
# 8> casey s vlogs almost didn t feel like casey s vlogs without the studio in them
#
# 9> casey the lock of the door should be on the inside  not the outside
#
# 10> my life feels that bit brighter knowing there s a casey upload always on the horizon  unmatched vibes

# %%
import matplotlib.pyplot as plt
from sklearn.feature_extraction import text 
from wordcloud import WordCloud

def generate_word_clouds(df):
  allWords = ' '.join([texts for texts in df['Comments']])
  wordCloud = WordCloud(stopwords = text.ENGLISH_STOP_WORDS ,width=1000, height=600, random_state=21, max_font_size=110).generate(allWords)
  plt.imshow(wordCloud, interpolation="bilinear")
  plt.axis('off')
  plt.show()

generate_word_clouds(df)

# %%
df['Analysis'].value_counts()["Positive"]
# Out:
# 73

# %%
df['Analysis'].value_counts()["Negative"]
# Out:
# 4

# %%
df['Analysis'].value_counts()["Neutral"]
# Out:
# 6

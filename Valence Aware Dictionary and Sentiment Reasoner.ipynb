# %%
import os 
from googleapiclient.discovery import build

# %%
def google_api(id):
    
    os.environ["0AUTHLIB_INSECURE_TRANSPORT"] = "1"
    api_key = "AIzaSyCfG3uF4Oiq1TCMZfYroYWAlpqdjHTgGak"

    youtube = build('youtube','v3',developerKey=api_key)
    request = youtube.commentThreads().list(
      part="id,snippet",
      maxResults=1500,
      order="relevance",
      videoId = id
  )

    response = request.execute()
    print(response)
    return response
  
response = google_api("931vR1c9yCs")
# Out:
# {'kind': 'youtube#commentThreadListResponse', 'etag': 'eLimvnQNkY-OyV7U7VC95AivIxQ', 'nextPageToken': '...', 'pageInfo': {'totalResults': 100, 'resultsPerPage': 100}, 'items': [{'kind': 'youtube#commentThread', 'etag': 'o4lwlXg4NT2RZBk-a2GxtnAoH6k', 'id': 'UgxitpY_Ej81_ZuWdBV4AaABAg', 'snippet': {'videoId': '931vR1c9yCs', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'a1Pr2_LMTxvWC3sugKBOzo6sUlU', 'id': 'UgxitpY_Ej81_ZuWdBV4AaABAg', 'snippet': {'videoId': '931vR1c9yCs', 'textDisplay': 'THANK YOU FOR ALL THE LOVE AND SUPPORT FAM &lt;3<br>Stream this song and the rest of my comment songs here! <a href="https://open.spotify.com/album/47fEKNMEr7PibTthZ9NU3b?si=Tya6fqY4TOiW1IZsY89Zuw&amp;dl_branch=1">https://open.spotify.com/album/47fEKNMEr7PibTthZ9NU3b?si=Tya6fqY4TOiW1IZsY89Zuw&amp;dl_branch=1</a>', 'textOriginal': 'THANK YOU FOR ALL THE LOVE AND SUPPORT FAM <3\nStream this song and the rest of my comment songs here! https://open.spotify.com/album/47fEKNMEr7PibTthZ9NU3b?si=Tya6f
# ...

# %%
import pandas as pd 
def create_df_author_comments():
    authorname = []
    comments = []
    like_Count = []
    for i in range(len(response["items"])):
        authorname.append(response["items"][i]["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"])
        comments.append(response["items"][i]["snippet"]["topLevelComment"]["snippet"]["textOriginal"])
        like_Count.append(response["items"][i]["snippet"]["topLevelComment"]["snippet"]["likeCount"])
        df = pd.DataFrame({'Comments':comments,"LikeCount":like_Count}, index = authorname) 
    return df 
df = create_df_author_comments()
df.head(50)
# Out:
#                                                                       Comments  \
# Madilyn Bailey               THANK YOU FOR ALL THE LOVE AND SUPPORT FAM <3\...
# whyisaubrey !                 I love how haters are spelling everything wrong.
# ItzScarlett²⁸💚💙              Lemme just list the list of wrong written “no ...
# Amber Real                   I love how the haters are saying no offence li...
# SweetBerries                 Lets just all take a moment to notice how amaz...
# JoDaSpec                     I love your covers and have listened for a whi...
# JJiscool                     Fun fact: putting "no offense" after a sentenc...
# KWS Music                    It's amazing how you made such a masterpiece s...
# Dora                         i remember watching this video and singing it ...
# Emily Thomson                I amazed how she can sing all these mean thing...
# Peaches and oranges          You’re amazing Madilyn don’t listen to haters ...
# ...

# %%
import re
def cleaning_comments(comment):
    comment = re.sub("[0-9]+","",comment)
    comment = re.sub("[\:|\@|\)|\*|\.|\$|\!|\?|\,|\%|\"]+"," ",comment)
    comment = re.sub("[\(|\-|\”|\“|\#|\/|\«|\»|\&]+","",comment)
    comment = re.sub("\n"," ",comment)
    comment = re.sub('[\'|🇵🇰|\;|]+','',comment)
    return comment

df["Comments"] = df["Comments"].apply(cleaning_comments)

# %%
def remove_comments(df):
    #Check for the comment that has Zero length in dataframe
    zero_length_comments = df[df["Comments"].map(len)==0]
    #Taking all the indexes of the filtered comments in a list
    zero_length_comments_index = [ind for ind in zero_length_comments.index]
    #removing those comments
    df.drop(zero_length_comments_index,inplace=True)
    return df

df = remove_comments(df)
df = df.drop_duplicates(subset='Comments', keep="first")
df.head(25)
# Out:
#                                                                  Comments  \
# Madilyn Bailey          THANK YOU FOR ALL THE LOVE AND SUPPORT FAM < S...
# whyisaubrey !            I love how haters are spelling everything wrong
# ItzScarlett²⁸💚💙         Lemme just list the list of wrong written no o...
# Amber Real              I love how the haters are saying no offence li...
# SweetBerries            Lets just all take a moment to notice how amaz...
# JoDaSpec                I love your covers and have listened for a whi...
# JJiscool                Fun fact  putting  no offense  after a sentenc...
# KWS Music               Its amazing how you made such a masterpiece so...
# Dora                    i remember watching this video and singing it ...
# Emily Thomson           I amazed how she can sing all these mean thing...
# Peaches and oranges     You’re amazing Madilyn don’t listen to haters ...
# Tracer 1273             Who knew no offense could be spelled in so man...
# ...

# %%
import nltk
nltk.downloader.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/phoenix_20/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()
sentiment = sid.polarity_scores("Hello Toronto")
print(sentiment)
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
from textblob.blob import TextBlob
def find_subjectivity_on_single_comment(text):
    return TextBlob(text).sentiment.subjectivity

def apply_subjectivity_on_all_comments(df):
    df['Subjectivity'] = df['Comments'].apply(find_subjectivity_on_single_comment)
    return df
df = apply_subjectivity_on_all_comments(df)

df
# def get_sentiment(sentence):
#      sentiment_score = sid.polarity_scores(sentence)
     
#      positive_meter = round((sentiment_score['pos'] * 10), 2)
#      negative_meter = round((sentiment_score['neg'] * 10), 2)
#      neutral_meter = round((sentiment_score)['neu']*10, 2)
#      compound_score = round((sentiment_score)['compound']*10, 2)
#      return positive_meter, negative_meter,neutral_meter, compound_score

# def find_polarity_of_single_comment(text):
#        return   sid.polarity_scores(text)

# def find_polarity_of_every_comment(df):  
#   df['Polarity'] = df['Comments'].apply(get_sentiment)

#   return df 

# df = find_polarity_of_every_comment(df)
# df
# Out:
#                                                           Comments  LikeCount  \
# Madilyn Bailey   THANK YOU FOR ALL THE LOVE AND SUPPORT FAM < S...      64221
# whyisaubrey !     I love how haters are spelling everything wrong       15156
# ItzScarlett²⁸💚💙  Lemme just list the list of wrong written no o...        205
# Amber Real       I love how the haters are saying no offence li...         88
# SweetBerries     Lets just all take a moment to notice how amaz...          7
# ...                                                            ...        ...
# Randall Griffin  Its so sad that people are so mean  but its bl...          0
# Cloudy Tears     The name of the song is  no offense  BTW HER V...        300
# RG                Great voice love it the way u compose this song           0
# Gracie Wood      Dont listen to the dumb  year olds  Youre amaz...          0
# Arwen H          The song is on Spotify  Check it out  in the l...          0
#
#                  Subjectivity
# ...

# %%
# df['Polarity'].tolist()
# pd.DataFrame(df['Polarity'].tolist(), index=df.index)

# %%
# df[['Positive Polarity', 'Negative Polarity','Neutral Polarity','Compound Polarity Score']] = pd.DataFrame(df['Polarity'].tolist(), index=df.index)

# %%
# df = df.drop(['Polarity'], axis=1)

# %%
# df.head(25)
# Out:
#                                                                  Comments  \
# Madilyn Bailey          THANK YOU FOR ALL THE LOVE AND SUPPORT FAM < S...
# whyisaubrey !            I love how haters are spelling everything wrong
# ItzScarlett²⁸💚💙         Lemme just list the list of wrong written no o...
# Amber Real              I love how the haters are saying no offence li...
# SweetBerries            Lets just all take a moment to notice how amaz...
# JoDaSpec                I love your covers and have listened for a whi...
# JJiscool                Fun fact  putting  no offense  after a sentenc...
# KWS Music               Its amazing how you made such a masterpiece so...
# Dora                    i remember watching this video and singing it ...
# Emily Thomson           I amazed how she can sing all these mean thing...
# Peaches and oranges     You’re amazing Madilyn don’t listen to haters ...
# Tracer 1273             Who knew no offense could be spelled in so man...
# ...

# %%
df_sort_values = df.sort_values(by='Subjectivity',ascending=False)

# %%
df_sort_values
# Out:
#                                                                      Comments  \
# Young Gaming1011            If this song needs a title   Ill name it  No O...
# ♡-It's Sparkles!-♡          Dont worry if someone hates you  EVERYONE IS P...
# mehwish khan                Just subscribed  God granted you a beautiful v...
# itz AlxD                    No ofense  offince  affense  offense but you s...
# Keisha The Banana Princess  Am I the only one laughing at the haters who s...
# ...                                                                       ...
# aditi Mani                  haters  affence affense offence afence offince...
# De lemonaders               every time i hear your voice  i feel like im i...
# Norman S.                   These haters cant even spell  no offense  corr...
# Just_me_dana                               She’s turning sh t into perfection
# Grace Fletcher              You voice blesses my ears dont listen to the h...
#
# ...
